# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'city': ['Varasnasi','Delhi','Patna','Supaul','Bgp']
})

# %%
df
# Out:
#         city
# 0  Varasnasi
# 1      Delhi
# 2      Patna
# 3     Supaul
# 4        Bgp

# %%
# one hot encoded
encoded = pd.get_dummies(df['city'])

# %%
print(encoded)
# Out:
#      Bgp  Delhi  Patna  Supaul  Varasnasi
# 0  False  False  False   False       True
# 1  False   True  False   False      False
# 2  False  False   True   False      False
# 3  False  False  False    True      False
# 4   True  False  False   False      False

# %%
encoded.astype(int)
# Out:
#    Bgp  Delhi  Patna  Supaul  Varasnasi
# 0    0      0      0       0          1
# 1    0      1      0       0          0
# 2    0      0      1       0          0
# 3    0      0      0       1          0
# 4    1      0      0       0          0
